# %%
from cf_ml.load_dataset import load_HELOC_dataset

# %%
dataset = load_HELOC_dataset()

# %%
d = dataset.get_dataset()
# Out:
# /Users/chengfurui/Projects/counterfactuals/cf_ml/dataset.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df[col] = (data_df[col] - minx)/(maxx-minx)

# %%
type(d.iloc[[0,1]])
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.get_description()
# Out:
# {'ExternalRiskEstimate': {'description': 'Consolidated version of risk markers',
#   'type': 'numerical',
#   'min': -9,
#   'max': 94,
#   'decile': 0,
#   'category': nan},
#  'MSinceOldestTradeOpen': {'description': 'Months Since Oldest Trade Open',
#   'type': 'numerical',
#   'min': -9,
#   'max': 803,
#   'decile': 0,
#   'category': nan},
#  'MSinceMostRecentTradeOpen': {'description': 'Months Since Most Recent Trade Open',
#   'type': 'numerical',
#   'min': -9,
#   'max': 383,
#   'decile': 0,
#   'category': nan},
#  'AverageMInFile': {'description': 'Average Months in File',
#   'type': 'numerical',
#   'min': -9,
#   'max': 383,
#   'decile': 0,
#   'category': nan},
#  'NumSatisfactoryTrades': {'description': 'Number Satisfactory Trades',
#   'type': 'numerical',
#   'min': -9,
#   'max': 79,
#   'decile': 0,
#   'category': nan},
#  'NumTrades60Ever2DerogPubRec': {'description': 'Number Trades 60+ Ever',
#   'type': 'numerical',
#   'min': -9,
#   'max': 19,
# ...

# %%
dataset.depreprocess(dataset.get_dataset())
# Out:
# /Users/chengfurui/Projects/counterfactuals/cf_ml/data_interface.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data_df[col] = data_df[col] * (maxx-minx) + minx
#       RiskPerformance  ExternalRiskEstimate  MSinceOldestTradeOpen  \
# 0                 Bad                  55.0                  144.0
# 1                 Bad                  61.0                   58.0
# 2                 Bad                  67.0                   66.0
# 3                 Bad                  66.0                  169.0
# 4                 Bad                  81.0                  333.0
# 5                 Bad                  59.0                  137.0
# 6                Good                  54.0                   88.0
# ...

# %%
origin = dataset.get_dataset(preprocess=False)

# %%
import numpy as np
origin[['MSinceOldestTradeOpen', 'ExternalRiskEstimate']].values.argmax(axis=1)np.array([1])
# Out:
# array([1, 2, 2, ..., 1, 1, 2])

# %%
dataset.get_dataset(preprocess=False).head(10)
# Out:
#   RiskPerformance  ExternalRiskEstimate  MSinceOldestTradeOpen  \
# 0             Bad                    55                    144
# 1             Bad                    61                     58
# 2             Bad                    67                     66
# 3             Bad                    66                    169
# 4             Bad                    81                    333
# 5             Bad                    59                    137
# 6            Good                    54                     88
# 7            Good                    68                    148
# 8             Bad                    59                    324
# 9             Bad                    61                     79
#
#    MSinceMostRecentTradeOpen  AverageMInFile  NumSatisfactoryTrades  \
# 0                          4              84                     20
# 1                         15              41                      2
# ...

# %%
import numpy as np
x = np.array([[1,2],[3,4]])

# %%
np.repeat(x, 3, axis=0)[0:3]
# Out:
# array([[1, 2],
#        [1, 2],
#        [1, 2]])
